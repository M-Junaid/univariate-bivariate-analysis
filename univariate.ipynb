# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("train.csv")

# %% [markdown]
# # 1.Catagorical Data
# ## a.Count Plot

# %%
sns.countplot(x=df["Survived"],data=df)
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df["Survived"].value_counts().plot(kind='bar')
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x="Pclass",data=df)
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(x="Sex",data=df)
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# ## b.Pie Chart

# %%
df["Survived"].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["Sex"].value_counts().plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["Pclass"].value_counts().plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 2.Numerical Data
#
# ## a.Histogram

# %%
import matplotlib.pyplot as plt
plt.hist(df["Age"],bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# ## b.Displot

# %%
sns.set_theme()
sns.distplot(df["Age"])           #Kernel density estimation
                                      #this plot is use to fin probability
# Out:
# C:\Users\M Junaid\AppData\Local\Temp\ipykernel_21576\3315154540.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# Showing a density curve

# %%
sns.distplot(df["Age"],hist=False)
# Out:
# C:\Users\M Junaid\AppData\Local\Temp\ipykernel_21576\2272999754.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# c.BoxPlot
#
#  this plot is use to find that how much the data is noisey/outlier is present in the data

# %%
sns.boxenplot(x=df["Fare"])
# Out:
# <Axes: xlabel='Fare'>

# %%
sns.boxenplot(x=df["Age"])
# Out:
# <Axes: xlabel='Age'>

# %%
df["Age"].min()
# Out:
# 0.42

# %%
df["Age"].max()
# Out:
# 80.0

# %%
df["Age"].mean()
# Out:
# 29.69911764705882

# %%
df["Age"].skew()
# Out:
# 0.38910778230082704
